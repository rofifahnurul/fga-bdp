# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

path = "Map-Crime_Incidents-Previous_Three_Months.csv"

df_compact = pd.read_csv(path)
df_compact.head(3)

# %%
path = "Map-Crime_Incidents-Previous_Three_Months.csv"

SFC = pd.read_csv(path)

# %%
SFC.head(5)
# Out:
#    IncidntNum       Category                        Descript DayOfWeek  \
# 0         NaN  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1         NaN  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2         NaN  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3         NaN  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4         NaN  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  \
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974
# ...

# %%
# !head -n 5 ../Users/Agussuyono/Documents/DTS/Map-Crime_Incidents-Previous_Three_Months.csv
# Out:
# Unknown option: n
# Usage: head [-options] <url>...
#     -m <method>   use method for the request (default is 'HEAD')
#     -f            make request even if head believes method is illegal
#     -b <base>     Use the specified URL as base
#     -t <timeout>  Set timeout value
#     -i <time>     Set the If-Modified-Since header on the request
#     -c <conttype> use this content-type for POST, PUT, CHECKIN
#     -a            Use text mode for content I/O
#     -p <proxyurl> use this as a proxy
#     -P            don't load proxy settings from environment
#     -H <header>   send this HTTP header (you can specify several)
#
#     -u            Display method and URL before any response
#     -U            Display request headers (implies -u)
#     -s            Display response status code
#     -S            Display response status chain
#     -e            Display response headers
#     -d            Do not display content
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# IncidntNum
# Category
# Descript
# DayOfWeek
# Date
# Time
# PdDistrict
# Resolution
# Address
# X
# Y
# Location

# %%
SFC.describe
# Out:
# <bound method NDFrame.describe of        IncidntNum        Category                               Descript  \
# 0             NaN   LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO
# 1             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 2             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 3             NaN   DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE
# 4             NaN   DRUG/NARCOTIC                  POSSESSION OF COCAINE
# ...           ...             ...                                    ...
# 30755         NaN   LARCENY/THEFT                PETTY THEFT SHOPLIFTING
# 30756         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 30757         NaN         ASSAULT                                BATTERY
# 30758         NaN         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS
# 30759         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
# ...

# %%
len(SFC)
# Out:
# 30760

# %%
SFC['Months'] = SFC['Date'].apply(lambda row:int(row[0:2]))

SFC['Day'] = SFC['Date'].apply(lambda row:int(row[3:5]))

# %%
for i in SFC['Months']:
    print(type(i))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
for i in SFC['Day']:
    print(i)
# Out:
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# ...

# %%
print(SFC['Day'][0])
# Out:
# 31

# %%
print(type(SFC['Day'][0]))
# Out:
# <class 'numpy.int64'>

# %%
#del SFC['IncidntNum'

# %%
SFC.head(5)
# Out:
#         Category                        Descript DayOfWeek  \
# 0  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  \
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974
# 1  COLUMBUS AV / JACKSON ST -122.404418  37.796302
# 2   SUTTER ST / STOCKTON ST -122.406959  37.789435
# ...

# %%
del SFC['Location']

# %%
SFC
# Out:
#              Category                               Descript DayOfWeek  \
# 0       LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1       LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO    Sunday
# 2       LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO    Sunday
# 3       DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE    Sunday
# 4       DRUG/NARCOTIC                  POSSESSION OF COCAINE    Sunday
# ...               ...                                    ...       ...
# 30755   LARCENY/THEFT                PETTY THEFT SHOPLIFTING    Sunday
# 30756  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED    Sunday
# 30757         ASSAULT                                BATTERY    Sunday
# 30758         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS    Sunday
# 30759  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED    Sunday
#
#                                Date   Time  PdDistrict      Resolution  \
# ...

# %%
CountCategory = SFC['Category'].value_counts()
print(CountCategory)
# Out:
# LARCENY/THEFT                  8205
# OTHER OFFENSES                 4004
# NON-CRIMINAL                   3653
# ASSAULT                        2518
# VEHICLE THEFT                  1885
# VANDALISM                      1611
# WARRANTS                       1583
# DRUG/NARCOTIC                  1292
# BURGLARY                       1257
# MISSING PERSON                 1135
# ROBBERY                         862
# SUSPICIOUS OCC                  682
# FRAUD                           574
# WEAPON LAWS                     322
# TRESPASS                        259
# DRUNKENNESS                     142
# KIDNAPPING                      128
# SEX OFFENSES, FORCIBLE          123
# DRIVING UNDER THE INFLUENCE      93
# FORGERY/COUNTERFEITING           88
# DISORDERLY CONDUCT               69
# RUNAWAY                          61
# ARSON                            60
# PROSTITUTION                     44
# LIQUOR LAWS                      38
# EMBEZZLEMENT                     19
# ...

# %%
CountCategory = SFC['Category'].value_counts(ascending=True)
print(CountCategory)
# Out:
# GAMBLING                          1
# BRIBERY                           1
# PORNOGRAPHY/OBSCENE MAT           1
# BAD CHECKS                        3
# SEX OFFENSES, NON FORCIBLE        5
# LOITERING                         5
# STOLEN PROPERTY                   7
# EXTORTION                         7
# FAMILY OFFENSES                   9
# SUICIDE                          14
# EMBEZZLEMENT                     19
# LIQUOR LAWS                      38
# PROSTITUTION                     44
# ARSON                            60
# RUNAWAY                          61
# DISORDERLY CONDUCT               69
# FORGERY/COUNTERFEITING           88
# DRIVING UNDER THE INFLUENCE      93
# SEX OFFENSES, FORCIBLE          123
# KIDNAPPING                      128
# DRUNKENNESS                     142
# TRESPASS                        259
# WEAPON LAWS                     322
# FRAUD                           574
# SUSPICIOUS OCC                  682
# ROBBERY                         862
# ...

# %%
pdDistrict = SFC['PdDistrict'].value_counts(ascending=False)
print(pdDistrict)
# Out:
# SOUTHERN      6185
# MISSION       4011
# CENTRAL       3867
# NORTHERN      3205
# BAYVIEW       2970
# INGLESIDE     2613
# TENDERLOIN    2449
# TARAVAL       2038
# PARK          1800
# RICHMOND      1622
# Name: PdDistrict, dtype: int64

# %%
augustCrime = SFC[SFC['Months'] == 8]

# %%
augustCrime
# Out:
#                          Category  \
# 0                   LARCENY/THEFT
# 1                   LARCENY/THEFT
# 2                   LARCENY/THEFT
# 3                   DRUG/NARCOTIC
# 4                   DRUG/NARCOTIC
# ...                           ...
# 9715                 NON-CRIMINAL
# 9716               OTHER OFFENSES
# 9717                      ASSAULT
# 9718  DRIVING UNDER THE INFLUENCE
# 9719       SEX OFFENSES, FORCIBLE
#
#                                           Descript DayOfWeek  \
# 0                   GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1                     GRAND THEFT FROM LOCKED AUTO    Sunday
# 2                     GRAND THEFT FROM LOCKED AUTO    Sunday
# 3                   POSSESSION OF METH-AMPHETAMINE    Sunday
# 4                            POSSESSION OF COCAINE    Sunday
# ...                                            ...       ...
# 9715                  AIDED CASE, MENTAL DISTURBED    Friday
# ...

# %%
burglariesCrime = augustCrime[augustCrime['Category'] == 'BURGLARY']
burglariesCrime

# %%
burglariesCrime
# Out:
#       Category                                           Descript DayOfWeek  \
# 185   BURGLARY                  BURGLARY OF STORE, UNLAWFUL ENTRY    Friday
# 212   BURGLARY      BURGLARY, HOT PROWL, ATTEMPTED FORCIBLE ENTRY    Friday
# 240   BURGLARY                BURGLARY, HOT PROWL, UNLAWFUL ENTRY  Thursday
# 251   BURGLARY  BURGLARY,STORE UNDER CONSTRUCTION, UNLAWFUL ENTRY  Thursday
# 262   BURGLARY    BURGLARY OF RESIDENCE, ATTEMPTED FORCIBLE ENTRY  Thursday
# ...        ...                                                ...       ...
# 9564  BURGLARY                           BURGLARY, FORCIBLE ENTRY    Friday
# 9579  BURGLARY                           BURGLARY, UNLAWFUL ENTRY    Friday
# 9615  BURGLARY        BURGLARY OF APARTMENT HOUSE, UNLAWFUL ENTRY    Friday
# 9616  BURGLARY  BURGLARY,STORE UNDER CONSTRUCTION, UNLAWFUL ENTRY    Friday
# 9627  BURGLARY        BURGLARY OF APARTMENT HOUSE, UNLAWFUL ENTRY    Friday
#
# ...

# %%
Crime0704 = SFC.query('Months == 7 and Day == 4')
Crime0704
# Out:
#              Category                                          Descript  \
# 19087   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19088   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19089        BURGLARY  BURGLARY,RESIDENCE UNDER CONSTRT, FORCIBLE ENTRY
# 19090    NON-CRIMINAL                                     LOST PROPERTY
# 19091         ASSAULT                                           BATTERY
# ...               ...                                               ...
# 19423   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19424  OTHER OFFENSES                         LOST/STOLEN LICENSE PLATE
# 19425   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19426   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19427   LARCENY/THEFT                           PETTY THEFT OF PROPERTY
#
#       DayOfWeek                          Date   Time PdDistrict Resolution  \
# ...

# %%
plt.plot(SFC['X'],SFC['Y'])
plt.show()

# %%
pd_districts = np.unique(SFC['PdDistrict'])
pd_districts_levels = dict(zip(pd_districts, range(len(pd_districts))))
pd_districts_levels
# Out:
# {'BAYVIEW': 0,
#  'CENTRAL': 1,
#  'INGLESIDE': 2,
#  'MISSION': 3,
#  'NORTHERN': 4,
#  'PARK': 5,
#  'RICHMOND': 6,
#  'SOUTHERN': 7,
#  'TARAVAL': 8,
#  'TENDERLOIN': 9}

# %%
SFC['PdDistrictId'] = SFC['PdDistrict'].apply(lambda row: int)
